# %%
import sys
sys.path.append('../scripts')
import eval
import data_loader
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dl = data_loader.DataLoader([100], test=True)
trunc_iter = dl.train_batch_iter(batch_size=10, num_epochs=1)
def next_trunc_ecal():
    trunc_ecal, _ = trunc_iter.next()
    return trunc_ecal[0]

# %%
ecals,_ = trunc_iter.next()

# %%
ecals.shape
# Out:
# (10, 20, 20, 25)

# %%
eval.plot_dispersion(ecals[1],ecals[2])
